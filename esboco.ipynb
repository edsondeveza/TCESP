# %%
import pandas as pd
import os
import datetime
import numpy as np

# %%
data = datetime.datetime.now()

# %%
# Criando df consolidado_despesas vazio

colunas_despesas = ['id_despesa_detalhe', 'ano_exercicio', 'ds_municipio', 'ds_orgao', 
                    'mes_referencia', 'mes_ref_extenso', 'tp_despesa', 'nr_empenho',
                    'identificador_despesa', 'ds_despesa', 'dt_emissao_despesa', 'vl_despesa', 
                    'ds_funcao_governo', 'ds_subfuncao_governo', 'cd_programa', 'ds_programa', 
                    'cd_acao', 'ds_acao', 'ds_fonte_recurso', 'ds_cd_aplicacao_fixo', 
                    'ds_modalidade_lic', 'ds_elemento', 'historico_despesa']

consolidado_despesas = pd.DataFrame(columns=colunas_despesas)

# %%
# Criando df consolidado_receitas vazio

colunas_receitas = ['id_rec_arrec_detalhe', 'ano_exercicio', 'ds_municipio', 'ds_orgao',
                    'mes_referencia', 'mes_ref_extenso', 'ds_poder', 'ds_fonte_recurso',
                    'ds_cd_aplicacao_fixo', 'ds_cd_aplicacao_variavel', 'ds_categoria', 
                    'ds_fonte', 'ds_rubrica', 'ds_alinea', 'ds_subalinea', 'vl_arrecadacao']

consolidado_receitas = pd.DataFrame(columns=colunas_receitas)

# %%
print(consolidado_despesas)
print(consolidado_receitas)
# Out:
# Empty DataFrame
# Columns: [id_despesa_detalhe, ano_exercicio, ds_municipio, ds_orgao, mes_referencia, mes_ref_extenso, tp_despesa, nr_empenho, identificador_despesa, ds_despesa, dt_emissao_despesa, vl_despesa, ds_funcao_governo, ds_subfuncao_governo, cd_programa, ds_programa, cd_acao, ds_acao, ds_fonte_recurso, ds_cd_aplicacao_fixo, ds_modalidade_lic, ds_elemento, historico_despesa]
# Index: []
#
# [0 rows x 23 columns]
# Empty DataFrame
# Columns: [id_rec_arrec_detalhe, ano_exercicio, ds_municipio, ds_orgao, mes_referencia, mes_ref_extenso, ds_poder, ds_fonte_recurso, ds_cd_aplicacao_fixo, ds_cd_aplicacao_variavel, ds_categoria, ds_fonte, ds_rubrica, ds_alinea, ds_subalinea, vl_arrecadacao]
# Index: []

# %%
# Criando variaveis com os arqquivos

arquivos_despesas = os.listdir('Despesas')
arquivos_receitas = os.listdir('Receitas')

# %%
print(arquivos_despesas)
print(arquivos_receitas)
# Out:
# ['Despesas-Cotia-2020.csv', 'Despesas-Cotia-2021.csv', 'Despesas-Cotia-2022.csv', 'Despesas-Cotia-2023.csv', 'Despesas-Embu das Artes-2020.csv', 'Despesas-Embu das Artes-2021.csv', 'Despesas-Embu das Artes-2022.csv', 'Despesas-Embu das Artes-2023.csv', 'Despesas-Itapecerica da Serra-2020.csv', 'Despesas-Itapecerica da Serra-2021.csv', 'Despesas-Itapecerica da Serra-2022.csv', 'Despesas-Itapecerica da Serra-2023.csv', 'Despesas-Taboao da Serra-2020.csv', 'Despesas-Taboao da Serra-2021.csv', 'Despesas-Taboao da Serra-2022.csv', 'Despesas-Taboao da Serra-2023.csv']
# ['Receitas-Cotia-2020.csv', 'Receitas-Cotia-2021.csv', 'Receitas-Cotia-2022.csv', 'Receitas-Cotia-2023.csv', 'Receitas-Embu das Artes-2020.csv', 'Receitas-Embu das Artes-2021.csv', 'Receitas-Embu das Artes-2022.csv', 'Receitas-Embu das Artes-2023.csv', 'Receitas-Itapecerica da Serra-2020.csv', 'Receitas-Itapecerica da Serra-2021.csv', 'Receitas-Itapecerica da Serra-2022.csv', 'Receitas-Itapecerica da Serra-2023.csv', 'Receitas-Taboao da Serra-2020.csv', 'Receitas-Taboao da Serra-2021.csv', 'Receitas-Taboao da Serra-2022.csv', 'Receitas-Taboao da Serra-2023.csv']

# %%
for arquivo_despesa in arquivos_despesas:
    
    if arquivo_despesa.endswith('.csv'):
        
        try:
            df = pd.read_csv(f'Despesas/{arquivo_despesa}', sep=(';'), encoding='ISO-8859-1')
            consolidado_despesas = pd.concat([df, consolidado_despesas], ignore_index=True)
        except Exception as e:
            with open('log_erros.txt', 'a') as file:
                file.write(f'Erro ao tentar consolidar o arquivo {arquivo_despesa}!\n')
                file.write(f'Detalhes do erro: {str(e)}\n\n')
                
    else:
        with open('log_erros.txt', 'a') as file:
                file.write(f'O arquivo {arquivo_despesa} não é um arquivo CSV válido!\n\n')

# %%
for arquivo in arquivos_receitas:
    
    if arquivo.endswith('.csv'):
        
        try:
            df = pd.read_csv(f'Receitas/{arquivo}', sep=(';'), encoding='ISO-8859-1')
            consolidado_receitas = pd.concat([df, consolidado_receitas], ignore_index=True)
        except Exception as e:
            with open('log_erros.txt', 'a') as file:
                file.write(f'Erro ao tentar consolidar o arquivo {arquivo}!\n')
                file.write(f'Detalhes do erro: {str(e)}\n\n')
                
    else:
        with open('log_erros.txt', 'a') as file:
                file.write(f'O arquivo {arquivo} não é um arquivo CSV válido!\n\n')

# %%
consolidado_despesas.head()
# Out:
#   id_despesa_detalhe ano_exercicio     ds_municipio  \
# 0          576010177          2023  Taboão da Serra
# 1          576010178          2023  Taboão da Serra
# 2          576010179          2023  Taboão da Serra
# 3          576010180          2023  Taboão da Serra
# 4          576010181          2023  Taboão da Serra
#
#                                   ds_orgao mes_referencia mes_ref_extenso  \
# 0  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 1  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 2  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 3  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 4  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
#
#   tp_despesa nr_empenho                    identificador_despesa  \
# 0  Empenhado   937-2023  CNPJ - PESSOA JURÍDICA - 29979036000140
# 1  Empenhado   376-2023  CNPJ - PESSOA JURÍDICA - 46523122000163
# 2  Empenhado   227-2023  CNPJ - PESSOA JURÍDICA - 08940472000136
# 3  Empenhado   938-2023  CNPJ - PESSOA JURÍDICA - 29979036000140
# 4  Empenhado   253-2023  CNPJ - PESSOA JURÍDICA - 46523122000163
#
#                                  ds_despesa  ... ds_subfuncao_governo  \
# 0  INSTITUTO NACIONAL DO SEGURO SOCIAL INSS  ...  ADMINISTRAÇÃO GERAL
# 1   PREFEITURA MUNICIPAL DE TABOAO DA SERRA  ...  ADMINISTRAÇÃO GERAL
# 2                                TABOAOPREV  ...  ADMINISTRAÇÃO GERAL
# 3  INSTITUTO NACIONAL DO SEGURO SOCIAL INSS  ...  ADMINISTRAÇÃO GERAL
# 4   PREFEITURA MUNICIPAL DE TABOAO DA SERRA  ...  ADMINISTRAÇÃO GERAL
#
#   cd_programa                 ds_programa cd_acao  \
# 0        1901  GESTAO DE RECURSOS HUMANOS    2191
# 1        1901  GESTAO DE RECURSOS HUMANOS    2191
# 2        1901  GESTAO DE RECURSOS HUMANOS    2191
# 3        1901  GESTAO DE RECURSOS HUMANOS    2191
# 4        1901  GESTAO DE RECURSOS HUMANOS    2191
#
#                             ds_acao ds_fonte_recurso ds_cd_aplicacao_fixo  \
# 0  MANUTENCAO DA FOLHA DE PAGAMENTO          TESOURO         0110 - GERAL
# 1  MANUTENCAO DA FOLHA DE PAGAMENTO          TESOURO         0110 - GERAL
# 2  MANUTENCAO DA FOLHA DE PAGAMENTO          TESOURO         0110 - GERAL
# 3  MANUTENCAO DA FOLHA DE PAGAMENTO          TESOURO         0110 - GERAL
# 4  MANUTENCAO DA FOLHA DE PAGAMENTO          TESOURO         0110 - GERAL
#
#       ds_modalidade_lic                                        ds_elemento  \
# 0  OUTROS/NÃO APLICÁVEL    31901302 - CONTRIBUIÇÕES PREVIDENCIÁRIAS - INSS
# 1  OUTROS/NÃO APLICÁVEL  31909498 - INDENIZAÇÕES POR DEMISSÃO E COM PRO...
# 2  OUTROS/NÃO APLICÁVEL  31911308 - CONTRIBUIÇÕES PREVIDENCIÁRIAS - RPP...
# 3  OUTROS/NÃO APLICÁVEL    31901302 - CONTRIBUIÇÕES PREVIDENCIÁRIAS - INSS
# 4  OUTROS/NÃO APLICÁVEL  31909498 - INDENIZAÇÕES POR DEMISSÃO E COM PRO...
#
#                   historico_despesa
# 0  FOLHA DE PAGAMENTO JANEIRO 2023
# 1  FOLHA DE PAGAMENTO JANEIRO 2023
# 2  FOLHA DE PAGAMENTO JANEIRO 2023
# 3  FOLHA DE PAGAMENTO JANEIRO 2023
# 4  FOLHA DE PAGAMENTO JANEIRO 2023
#
# [5 rows x 23 columns]

# %%
consolidado_receitas.head()
# Out:
#   id_rec_arrec_detalhe ano_exercicio     ds_municipio  \
# 0             40187268          2023  Taboão da Serra
# 1             40187269          2023  Taboão da Serra
# 2             40187270          2023  Taboão da Serra
# 3             40187272          2023  Taboão da Serra
# 4             40187273          2023  Taboão da Serra
#
#                                   ds_orgao mes_referencia mes_ref_extenso  \
# 0  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 1  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 2  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 3  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
# 4  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA              1         Janeiro
#
#     ds_poder ds_fonte_recurso ds_cd_aplicacao_fixo  \
# 0  EXECUTIVO     01 - TESOURO    100 - GERAL TOTAL
# 1  EXECUTIVO     01 - TESOURO    100 - GERAL TOTAL
# 2  EXECUTIVO     01 - TESOURO    100 - GERAL TOTAL
# 3  EXECUTIVO     01 - TESOURO    100 - GERAL TOTAL
# 4  EXECUTIVO     01 - TESOURO          110 - GERAL
#
#                             ds_cd_aplicacao_variavel  \
# 0                 16 - ILUMINACAO PUBLICA (45.097-9)
# 1                 16 - ILUMINACAO PUBLICA (45.097-9)
# 2  21 - LEI COMPLEMENTAR 151 - RESGATE DEPOSITO J...
# 3                             21 - RECEITA DE SUCATA
# 4  00 - CÓDIGO DE APLICAÇÃO NÃO CONTÉM/INFORMOU P...
#
#                     ds_categoria  \
# 0  10000000 - Receitas Correntes
# 1  10000000 - Receitas Correntes
# 2  10000000 - Receitas Correntes
# 3  10000000 - Receitas Correntes
# 4  10000000 - Receitas Correntes
#
#                                      ds_subcategoria  \
# 0                           12000000 - Contribuições
# 1                     13000000 - Receita Patrimonial
# 2                     13000000 - Receita Patrimonial
# 3                     13000000 - Receita Patrimonial
# 4  11000000 - Impostos, Taxas e Contribuições de ...
#
#                                             ds_fonte  \
# 0  12400000 - Contribuição para o Custeio do Serv...
# 1                     13200000 - Valores Mobiliários
# 2                     13200000 - Valores Mobiliários
# 3                     13200000 - Valores Mobiliários
# 4                                11100000 - Impostos
#
#                                           ds_rubrica  \
# 0  12410000 - Contribuição para o Custeio do Serv...
# 1            13210000 - Juros e Correções Monetárias
# 2            13210000 - Juros e Correções Monetárias
# 3            13210000 - Juros e Correções Monetárias
# 4             11120000 - Impostos sobre o Patrimônio
#
#                                            ds_alinea ds_subalinea  \
# 0  12415000 - Contribuição para o Custeio do Serv...          NaN
# 1      13210100 - Remuneração de Depósitos Bancários          NaN
# 2      13210100 - Remuneração de Depósitos Bancários          NaN
# 3      13210100 - Remuneração de Depósitos Bancários          NaN
# 4  11125000 - Imposto sobre a Propriedade Predial...          NaN
#
#   vl_arrecadacao
# 0     1154919,33
# 1       28296,65
# 2        9002,63
# 3         769,22
# 4       71218,58

# %%
# Selecionando colunas desejadas e criando um novo df_despesas

colunas_desejadas = ['ano_exercicio', 'mes_ref_extenso', 'ds_municipio', 'ds_orgao',
                     'tp_despesa', 'identificador_despesa', 'dt_emissao_despesa',
                     'vl_despesa', 'ds_funcao_governo', 'ds_programa', 'ds_modalidade_lic']

df_despesas = consolidado_despesas[colunas_desejadas]

# %%
df_despesas.head()
# Out:
#   ano_exercicio mes_ref_extenso     ds_municipio  \
# 0          2023         Janeiro  Taboão da Serra
# 1          2023         Janeiro  Taboão da Serra
# 2          2023         Janeiro  Taboão da Serra
# 3          2023         Janeiro  Taboão da Serra
# 4          2023         Janeiro  Taboão da Serra
#
#                                   ds_orgao tp_despesa  \
# 0  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA  Empenhado
# 1  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA  Empenhado
# 2  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA  Empenhado
# 3  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA  Empenhado
# 4  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA  Empenhado
#
#                      identificador_despesa dt_emissao_despesa vl_despesa  \
# 0  CNPJ - PESSOA JURÍDICA - 29979036000140         18/01/2023    7552,40
# 1  CNPJ - PESSOA JURÍDICA - 46523122000163         02/01/2023      47,50
# 2  CNPJ - PESSOA JURÍDICA - 08940472000136         02/01/2023   14685,41
# 3  CNPJ - PESSOA JURÍDICA - 29979036000140         18/01/2023    3617,92
# 4  CNPJ - PESSOA JURÍDICA - 46523122000163         02/01/2023    5700,00
#
#   ds_funcao_governo                 ds_programa     ds_modalidade_lic
# 0     ADMINISTRAÇÃO  GESTAO DE RECURSOS HUMANOS  OUTROS/NÃO APLICÁVEL
# 1     ADMINISTRAÇÃO  GESTAO DE RECURSOS HUMANOS  OUTROS/NÃO APLICÁVEL
# 2     ADMINISTRAÇÃO  GESTAO DE RECURSOS HUMANOS  OUTROS/NÃO APLICÁVEL
# 3     ADMINISTRAÇÃO  GESTAO DE RECURSOS HUMANOS  OUTROS/NÃO APLICÁVEL
# 4     ADMINISTRAÇÃO  GESTAO DE RECURSOS HUMANOS  OUTROS/NÃO APLICÁVEL

# %%
# Selecionando colunas desejadas e criando um novo df_receitas

colunas_desejadas = ['ano_exercicio', 'mes_ref_extenso','ds_municipio', 'ds_orgao', 
                     'ds_fonte_recurso', 'ds_categoria', 'vl_arrecadacao']

df_receitas = consolidado_receitas[colunas_desejadas]

# %%
df_receitas.head()
# Out:
#   ano_exercicio mes_ref_extenso     ds_municipio  \
# 0          2023         Janeiro  Taboão da Serra
# 1          2023         Janeiro  Taboão da Serra
# 2          2023         Janeiro  Taboão da Serra
# 3          2023         Janeiro  Taboão da Serra
# 4          2023         Janeiro  Taboão da Serra
#
#                                   ds_orgao ds_fonte_recurso  \
# 0  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA     01 - TESOURO
# 1  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA     01 - TESOURO
# 2  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA     01 - TESOURO
# 3  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA     01 - TESOURO
# 4  PREFEITURA MUNICIPAL DE TABOÃO DA SERRA     01 - TESOURO
#
#                     ds_categoria vl_arrecadacao
# 0  10000000 - Receitas Correntes     1154919,33
# 1  10000000 - Receitas Correntes       28296,65
# 2  10000000 - Receitas Correntes        9002,63
# 3  10000000 - Receitas Correntes         769,22
# 4  10000000 - Receitas Correntes       71218,58

# %%
print(df_despesas.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785280 entries, 0 to 785279
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ano_exercicio          785280 non-null  object
#  1   mes_ref_extenso        785280 non-null  object
#  2   ds_municipio           785280 non-null  object
#  3   ds_orgao               785280 non-null  object
#  4   tp_despesa             785280 non-null  object
#  5   identificador_despesa  785280 non-null  object
#  6   dt_emissao_despesa     785280 non-null  object
#  7   vl_despesa             785280 non-null  object
#  8   ds_funcao_governo      785280 non-null  object
#  9   ds_programa            785280 non-null  object
#  10  ds_modalidade_lic      785280 non-null  object
# dtypes: object(11)
# memory usage: 65.9+ MB
# None

# %%
print(df_receitas.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32023 entries, 0 to 32022
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ano_exercicio     32023 non-null  object
#  1   mes_ref_extenso   32023 non-null  object
#  2   ds_municipio      32023 non-null  object
#  3   ds_orgao          32023 non-null  object
#  4   ds_fonte_recurso  32023 non-null  object
#  5   ds_categoria      32023 non-null  object
#  6   vl_arrecadacao    32023 non-null  object
# dtypes: object(7)
# memory usage: 1.7+ MB
# None

# %%
# Trando dados substituindo , por . na colunas de valores monetários dos dfs
df_despesas.loc[:, 'vl_despesa'] = df_despesas['vl_despesa'].str.replace(',', '.')
df_receitas.loc[:, 'vl_arrecadacao'] = df_receitas['vl_arrecadacao'].str.replace(',', '.')

# %%
# alterando tipo de string para float64 das colunas de valores monetários
df_despesas = df_despesas.astype({'vl_despesa' : 'float64'})
df_receitas = df_receitas.astype({'vl_arrecadacao' : 'float64'})

# %%
# alterando tipo de string para data da coluna dt_emissao_despesa
df_despesas['dt_emissao_despesa'] = pd.to_datetime(df_despesas['dt_emissao_despesa'], format='%d/%m/%Y')

# %%
# Visualizando dados faltantes
df_despesas.isnull().sum() / df_despesas.shape[0] * 100
# Out:
# ano_exercicio            0.0
# mes_ref_extenso          0.0
# ds_municipio             0.0
# ds_orgao                 0.0
# tp_despesa               0.0
# identificador_despesa    0.0
# dt_emissao_despesa       0.0
# vl_despesa               0.0
# ds_funcao_governo        0.0
# ds_programa              0.0
# ds_modalidade_lic        0.0
# dtype: float64

# %%
# Visualizando dados faltantes

df_receitas.isnull().sum() / df_despesas.shape[0] * 100
# Out:
# ano_exercicio       0.0
# mes_ref_extenso     0.0
# ds_municipio        0.0
# ds_orgao            0.0
# ds_fonte_recurso    0.0
# ds_categoria        0.0
# vl_arrecadacao      0.0
# dtype: float64

# %%
df_despesas.set_index('dt_emissao_despesa', inplace=True)

# %%
df_despesas['vl_despesa'].describe().round()
# Out:
# count       785280.0
# mean         69372.0
# std         662693.0
# min       -6649198.0
# 25%            652.0
# 50%           3333.0
# 75%          17184.0
# max      192965368.0
# Name: vl_despesa, dtype: float64

# %%
df_despesas['vl_despesa'].median()
# Out:
# 3333.33

# %%
df_despesas['vl_despesa'].mean()
# Out:
# 69371.85577535402

# %%
df_despesas.groupby('ds_municipio').sum(numeric_only=True)
# Out:
#                         vl_despesa
# ds_municipio
# Cotia                 1.949379e+10
# Embu das Artes        1.345698e+10
# Itapecerica da Serra  8.193215e+09
# Taboão da Serra       1.333234e+10

# %%
df_despesas.groupby('ds_municipio')['vl_despesa'].mean()
# Out:
# ds_municipio
# Cotia                   142726.972019
# Embu das Artes           90156.779377
# Itapecerica da Serra     28785.391929
# Taboão da Serra          62066.898711
# Name: vl_despesa, dtype: float64

# %%
df_despesas.to_excel(f"Despesas-consolidado-{data.strftime('%d-%m-%Y')}.xlsx", 
                     index=False,
                     sheet_name='despesas_consolidado')

# %%
df_receitas.to_excel(f"Receitas-consolidado-{data.strftime('%d-%m-%Y')}.xlsx", 
                     index=False,
                     sheet_name='receitas_consolidado')

# %%
print(type(data))
# Out:
# <class 'datetime.datetime'>
